# %%
import pandas as pd
from bs4 import BeautifulSoup
import smtplib
import requests
import time
import datetime

# %%
# celulares

URL = "https://www.argentinacolor.com/listado/electronica-audio-video/televisores/tv"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"}
page = requests.get(URL,headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
prices = soup2.find_all('span', attrs={'class':'price-tag-text-sr-only'})
names = soup2.find_all('h2', attrs={'class':'ui-search-item__title'})
print(prices)
print(names)
# Out:
# [<span class="price-tag-text-sr-only">
#                    78271 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    152197 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    69709 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    121729 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    285737 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    201026 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    111475 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    146389 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    55566 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    569134 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    453108 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    92944 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    93878 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    102512 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    238710 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    126831 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    339301 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    123279 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    58090 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    65983 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    479289 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    381578 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    58090 pesos
#                   </span>]
# [<h2 class="ui-search-item__title">
#               Smart Tv Philips 43 Pulgadas Led Full Hd 43pfd6825
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung 50 4k Utrahd Crystal Un50au7000gczb
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung 32 Led Hd Un32t4300agczb Cuo
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Skyworth 50 Pulgadas Led 4k Uhd Frameless Androidtv
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung Qled 55 4k Frame Marrón Qn55ls03aagczbc
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Led LG 55 Nano Cell Uhd 4k 55nano80 Wifi Netflix
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Hyundai 50 4k Televisor Google Android
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 4k Uhd 50 Pulgada 50pud7406/77 Android X18c
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 32 Pulgadas Fullhd Blanco 32phd6926/77
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv LG Ai Thinq Oled65a1 65pulgadas 4k Ips Hdr
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 75 Pulgadas 4k Ultrahd Android 75pud8516
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 43 Pulgadas Led Full Hd 43pfd6825
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Hyundai 50 4k Televisor Google Android
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Skyworth 50 Pulgadas Led 4k Uhd Frameless Androidtv
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Led LG 55 Nano Cell Uhd 4k 55nano80 Wifi Netflix
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung 50 Crystal 4k Uhd Un50au7000gczb
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung Qled 55 4k Frame Marrón Qn55ls03aagczbc
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 50 Pulgadas 7000 Series Led 4k 220v
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung 32 Pulgadas Led Hd Un32t4300agczb
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 32 Pulgadas Fullhd Blanco 32phd6926/77
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv LG Ai Thinq Oled65a1 65pulgadas 4k Ips Hdr
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Philips 75 Pulgadas 4k Uhd Ambilight Android
#              </h2>, <h2 class="ui-search-item__title">
#               Smart Tv Samsung Un32t4300agxzd Led Hd 32  Cuotas
#              </h2>]

# %%
# get price list and name list
pricelist=[]
for span in prices:
    print(span.string)
    pricelist.append(span.string.strip())

namelist=[]
for h2 in names:
    print(h2.string)
    namelist.append(h2.string.strip())
# Out:
#                    78271 pesos
#
#
#                    152197 pesos
#
#
#                    69709 pesos
#
#
#                    121729 pesos
#
#
#                    285737 pesos
#
#
#                    201026 pesos
#
#
#                    111475 pesos
#
#
#                    146389 pesos
#
#
#                    55566 pesos
#
#
#                    569134 pesos
#
#
#                    453108 pesos
#
#
#                    92944 pesos
#
#
#                    93878 pesos
#
#
#                    102512 pesos
#
#
#                    238710 pesos
#
#
#                    126831 pesos
#
#
#                    339301 pesos
#
#
#                    123279 pesos
#
#
#                    58090 pesos
#
#
#                    65983 pesos
#
#
#                    479289 pesos
#
#
#                    381578 pesos
#
#
#                    58090 pesos
#
#
#               Smart Tv Philips 43 Pulgadas Led Full Hd 43pfd6825
#
#
#               Smart Tv Samsung 50 4k Utrahd Crystal Un50au7000gczb
#
#
#               Smart Tv Samsung 32 Led Hd Un32t4300agczb Cuo
#
#
#               Smart Tv Skyworth 50 Pulgadas Led 4k Uhd Frameless Androidtv
#
#
#               Smart Tv Samsung Qled 55 4k Frame Marrón Qn55ls03aagczbc
#
#
#               Smart Tv Led LG 55 Nano Cell Uhd 4k 55nano80 Wifi Netflix
#
#
#               Smart Tv Hyundai 50 4k Televisor Google Android
#
#
#               Smart Tv Philips 4k Uhd 50 Pulgada 50pud7406/77 Android X18c
#
#
#               Smart Tv Philips 32 Pulgadas Fullhd Blanco 32phd6926/77
#
#
#               Smart Tv LG Ai Thinq Oled65a1 65pulgadas 4k Ips Hdr
#
#
#               Smart Tv Philips 75 Pulgadas 4k Ultrahd Android 75pud8516
#
#
#               Smart Tv Philips 43 Pulgadas Led Full Hd 43pfd6825
#
#
#               Smart Tv Hyundai 50 4k Televisor Google Android
#
#
#               Smart Tv Skyworth 50 Pulgadas Led 4k Uhd Frameless Androidtv
#
#
#               Smart Tv Led LG 55 Nano Cell Uhd 4k 55nano80 Wifi Netflix
#
#
#               Smart Tv Samsung 50 Crystal 4k Uhd Un50au7000gczb
#
#
#               Smart Tv Samsung Qled 55 4k Frame Marrón Qn55ls03aagczbc
#
#
#               Smart Tv Philips 50 Pulgadas 7000 Series Led 4k 220v
#
#
#               Smart Tv Samsung 32 Pulgadas Led Hd Un32t4300agczb
#
#
#               Smart Tv Philips 32 Pulgadas Fullhd Blanco 32phd6926/77
#
#
#               Smart Tv LG Ai Thinq Oled65a1 65pulgadas 4k Ips Hdr
#
#
#               Smart Tv Philips 75 Pulgadas 4k Uhd Ambilight Android
#
#
#               Smart Tv Samsung Un32t4300agxzd Led Hd 32  Cuotas

# %%
# remove values with "antes"
pricelistp = [x for x in pricelist if "Antes:" not in x]
print(pricelistp)
# Out:
# ['78271 pesos', '152197 pesos', '69709 pesos', '121729 pesos', '285737 pesos', '201026 pesos', '111475 pesos', '146389 pesos', '55566 pesos', '569134 pesos', '453108 pesos', '92944 pesos', '93878 pesos', '102512 pesos', '238710 pesos', '126831 pesos', '339301 pesos', '123279 pesos', '58090 pesos', '65983 pesos', '479289 pesos', '381578 pesos', '58090 pesos']

# %%
print(len(pricelistp))
print(len(namelist))
# Out:
# 23
# 23

# %%
joindata = list(zip(pricelistp,namelist))
print(joindata)
# Out:
# [('78271 pesos', 'Smart Tv Philips 43 Pulgadas Led Full Hd 43pfd6825'), ('152197 pesos', 'Smart Tv Samsung 50 4k Utrahd Crystal Un50au7000gczb'), ('69709 pesos', 'Smart Tv Samsung 32 Led Hd Un32t4300agczb Cuo'), ('121729 pesos', 'Smart Tv Skyworth 50 Pulgadas Led 4k Uhd Frameless Androidtv'), ('285737 pesos', 'Smart Tv Samsung Qled 55 4k Frame Marrón Qn55ls03aagczbc'), ('201026 pesos', 'Smart Tv Led LG 55 Nano Cell Uhd 4k 55nano80 Wifi Netflix'), ('111475 pesos', 'Smart Tv Hyundai 50 4k Televisor Google Android'), ('146389 pesos', 'Smart Tv Philips 4k Uhd 50 Pulgada 50pud7406/77 Android X18c'), ('55566 pesos', 'Smart Tv Philips 32 Pulgadas Fullhd Blanco 32phd6926/77'), ('569134 pesos', 'Smart Tv LG Ai Thinq Oled65a1 65pulgadas 4k Ips Hdr'), ('453108 pesos', 'Smart Tv Philips 75 Pulgadas 4k Ultrahd Android 75pud8516'), ('92944 pesos', 'Smart Tv Philips 43 Pulgadas Led Full Hd 43pfd6825'), ('93878 pesos', 'Smart Tv Hyundai 50 4k Televisor Google Android'), ('102512 pesos', 'Smart Tv Skyworth 50 Pulgadas Led 4k Uhd Frameless Androidtv'), ('238710 pesos', 'Smart Tv Led LG 55 Nano Cell Uhd 4k 55nano80 Wifi Netflix'), ('126831 pesos', 'Smart Tv Samsung 50 Crystal 4k Uhd Un50au7000gczb'), ('339301 pesos', 'Smart Tv Samsung Qled 55 4k Frame Marrón Qn55ls03aagczbc'), ('123279 pesos', 'Smart Tv Philips 50 Pulgadas 7000 Series Led 4k 220v'), ('58090 pesos', 'Smart Tv Samsung 32 Pulgadas Led Hd Un32t4300agczb'), ('65983 pesos', 'Smart Tv Philips 32 Pulgadas Fullhd Blanco 32phd6926/77'), ('479289 pesos', 'Smart Tv LG Ai Thinq Oled65a1 65pulgadas 4k Ips Hdr'), ('381578 pesos', 'Smart Tv Philips 75 Pulgadas 4k Uhd Ambilight Android'), ('58090 pesos', 'Smart Tv Samsung Un32t4300agxzd Led Hd 32  Cuotas')]

# %%
# export data to csv

import csv
fields = ['product','price']
rows = joindata

with open ('ArgColorTelevisores.csv', 'w', newline='') as f:
    write = csv.writer(f)
    write.writerow(fields)
    write.writerows(rows)
