# %%
import pandas as pd
from bs4 import BeautifulSoup
import smtplib
import requests
import time
import datetime

# %%
# celulares

URL = "https://www.argentinacolor.com/celulares"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"}
page = requests.get(URL,headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
prices = soup2.find_all('span', attrs={'class':'price-tag-text-sr-only'})
names = soup2.find_all('h2', attrs={'class':'ui-search-item__title'})
print(prices)
print(names)
# Out:
# [<span class="price-tag-text-sr-only">
#                   Antes: 17502 pesos con 69 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    16628 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    391613 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 41203 pesos con 15 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    39143 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 18413 pesos con 92 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    17493 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 91158 pesos con 38 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    86600 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 39758 pesos con 46 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    37771 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    190265 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    82785 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    112856 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 80139 pesos con 01 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    76132 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 82560 pesos con 04 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    78432 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 72499 pesos con 07 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    68874 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 210041 pesos con 70 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    199540 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 49608 pesos con 46 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    47128 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    20773 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 33481 pesos con 42 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    31807 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 20783 pesos con 35 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    19744 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    69717 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    95210 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    465023 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 95162 pesos con 17 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    90404 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    94118 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    160229 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    168040 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 42615 pesos con 20 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    40484 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    31194 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    36463 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    39758 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 46673 pesos con 38 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    44340 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    33481 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 50603 pesos con 74 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    48074 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    36780 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 46109 pesos con 42 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    43804 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    42522 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    56609 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 54752 pesos con 16 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    52015 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    461 pesos con 86 centavos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 105279 pesos con 08 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    100015 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    3476 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 3650 pesos con 99 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    3468 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    6614 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    402 pesos con 06 centavos
#                   </span>, <span class="price-tag-text-sr-only">
#                    5571 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    239 pesos con 17 centavos
#                   </span>, <span class="price-tag-text-sr-only">
#                    2927 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    338 pesos con 66 centavos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 3075 pesos con 20 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    2921 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    199 pesos con 43 centavos
#                   </span>, <span class="price-tag-text-sr-only">
#                    50876 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    42845 pesos
#                   </span>]
# [<h2 class="ui-search-item__title">
#               Celular Zte Blade A31 Negro 1gb Ram 32gb Rom
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy Z Fold3 5g 256gb + 12gb Negro  Sm-f926bzkaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 64 Gb 4 Gb Ram Negro
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Alcatel 1 Plus 16gb Rom 1gb Ram Volcano Black
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A33 5g Awesome Black 128gb Rom 6gb Ram
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Samsung Galaxy A03 Core 2gb 32gb Negro Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Xiaomi Poco F3 5g Dual Sim 128 Gb Negro Nocturno 6 Gb Ram
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Xiaomi Redmi 9c Dual Sim 4gb Ram + 128 Gb Purpura Cu
#              </h2>, <h2 class="ui-search-item__title">
#               Xiaomi Redmi 10 Dual Sim 128 Gb 4 Gb Ram Carbon Gray Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A23 128gb + 4gb Ram Black Sm-a235mzkearo
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A32 128gb Rom 4gb Ram Awesome White
#              </h2>, <h2 class="ui-search-item__title">
#               Motorola G52 Negro 6gb+128gb Pau60016ar
#              </h2>, <h2 class="ui-search-item__title">
#               Xiaomi Mi 11 Lite Negro 5g Ne 8gb+256gb
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 64gb + 4gb Negro
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Alcatel 1 Plus 16gb Rom 1gb Ram Volcano Black Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Samsung Galaxy A03 Core 2gb 32gb Negro
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Zte Blade A31 Negro 1gb Ram 32gb Rom
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Xiaomi Redmi 9c Dual Sim 4gb Ram + 128 Gb Purpura
#              </h2>, <h2 class="ui-search-item__title">
#               Xiaomi Redmi 10 Dual Sim 128 Gb 4 Gb Ram Carbon Gray
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy Z Fold3 5g 256gb + 12gb Negro Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A23 128gb + 4gb Ram Black Sm-a235mzkearo
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A32 128gb 4gb Ram Awesome White
#              </h2>, <h2 class="ui-search-item__title">
#               Xiaomi Poco F3 128gb + 6gb Night Black
#              </h2>, <h2 class="ui-search-item__title">
#               Celular Xiaomi Mi 11 Lite Negro 5g Ne 8gb+256gb
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 3gb 32gb Negro Sm-a035mzkaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 Core 2gb 32gb Verde Menta Sm-a032mlgaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 3gb 32gb Azul Sm-a035mzbaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 Core 2gb 32gb Azul Sm-a032mzbaaro Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 4gb 128gb Negro Sm-a035mzkfaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 Core 2gb 32gb Azul Sm-a032mzbaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 3gb 32gb Negro Sm-a035mzkaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 Core 2gb 32gb Verde Menta Sm-a032mlgaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 4gb 64gb Azul Sm-a035mzbearo
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 3gb 32gb Azul Sm-a035mzbaaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 Negro 128gb + 4gb Sm-a035mzkfaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 Azul 64gb + 4gb Sm-a035mzbearo
#              </h2>, <h2 class="ui-search-item__title">
#               Cable Kolke Usb Para iPhone 6 7 8 Plus Xs Xr 11 Pro Max 1 Mt
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A33 128gb + 6gb 5g Awesome Black
#              </h2>, <h2 class="ui-search-item__title">
#               Cargador De Pared Tagwood Ichar34 Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Auriculares Maxell Solid+ Sin-8 Bluetooth Inalambricos
#              </h2>, <h2 class="ui-search-item__title">
#               Cable De Datos Apple Doc Usb Ma591
#              </h2>, <h2 class="ui-search-item__title">
#               Mercado Pago Point Mini Cobra Desde Tu Celular Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Cable De Datos Apple Doc Usb Ma591
#              </h2>, <h2 class="ui-search-item__title">
#               Funda Para Samsung S3 Candyshell Negro Speck Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Cargador De Pared Tagwood Ichar34
#              </h2>, <h2 class="ui-search-item__title">
#               Mercado Pago Point Mini Cobra Desde Tu Celular
#              </h2>, <h2 class="ui-search-item__title">
#               Auriculares Maxell Solid+ Sin-8 Bluetooth Inalambricos
#              </h2>, <h2 class="ui-search-item__title">
#               Funda Para Samsung S3 Candyshell Negro Speck
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 128 Gb 4 Gb Ram Negro Sm-a035mzkfaro
#              </h2>, <h2 class="ui-search-item__title">
#               Samsung Galaxy A03 128 Gb 4 Gb Ram Negro Sm-a035mzkfaro
#              </h2>]

# %%
# get price list and name list
pricelist=[]
for span in prices:
    print(span.string)
    pricelist.append(span.string.strip())

namelist=[]
for h2 in names:
    print(h2.string)
    namelist.append(h2.string.strip())
# Out:
#                   Antes: 17502 pesos con 69 centavos
#
#
#                    16628 pesos
#
#
#                    391613 pesos
#
#
#                   Antes: 41203 pesos con 15 centavos
#
#
#                    39143 pesos
#
#
#                   Antes: 18413 pesos con 92 centavos
#
#
#                    17493 pesos
#
#
#                   Antes: 91158 pesos con 38 centavos
#
#
#                    86600 pesos
#
#
#                   Antes: 39758 pesos con 46 centavos
#
#
#                    37771 pesos
#
#
#                    190265 pesos
#
#
#                    82785 pesos
#
#
#                    112856 pesos
#
#
#                   Antes: 80139 pesos con 01 centavos
#
#
#                    76132 pesos
#
#
#                   Antes: 82560 pesos con 04 centavos
#
#
#                    78432 pesos
#
#
#                   Antes: 72499 pesos con 07 centavos
#
#
#                    68874 pesos
#
#
#                   Antes: 210041 pesos con 70 centavos
#
#
#                    199540 pesos
#
#
#                   Antes: 49608 pesos con 46 centavos
#
#
#                    47128 pesos
#
#
#                    20773 pesos
#
#
#                   Antes: 33481 pesos con 42 centavos
#
#
#                    31807 pesos
#
#
#                   Antes: 20783 pesos con 35 centavos
#
#
#                    19744 pesos
#
#
#                    69717 pesos
#
#
#                    95210 pesos
#
#
#                    465023 pesos
#
#
#                   Antes: 95162 pesos con 17 centavos
#
#
#                    90404 pesos
#
#
#                    94118 pesos
#
#
#                    160229 pesos
#
#
#                    168040 pesos
#
#
#                   Antes: 42615 pesos con 20 centavos
#
#
#                    40484 pesos
#
#
#                    31194 pesos
#
#
#                    36463 pesos
#
#
#                    39758 pesos
#
#
#                   Antes: 46673 pesos con 38 centavos
#
#
#                    44340 pesos
#
#
#                    33481 pesos
#
#
#                   Antes: 50603 pesos con 74 centavos
#
#
#                    48074 pesos
#
#
#                    36780 pesos
#
#
#                   Antes: 46109 pesos con 42 centavos
#
#
#                    43804 pesos
#
#
#                    42522 pesos
#
#
#                    56609 pesos
#
#
#                   Antes: 54752 pesos con 16 centavos
#
#
#                    52015 pesos
#
#
#                    461 pesos con 86 centavos
#
#
#                   Antes: 105279 pesos con 08 centavos
#
#
#                    100015 pesos
#
#
#                    3476 pesos
#
#
#                   Antes: 3650 pesos con 99 centavos
#
#
#                    3468 pesos
#
#
#                    6614 pesos
#
#
#                    402 pesos con 06 centavos
#
#
#                    5571 pesos
#
#
#                    239 pesos con 17 centavos
#
#
#                    2927 pesos
#
#
#                    338 pesos con 66 centavos
#
#
#                   Antes: 3075 pesos con 20 centavos
#
#
#                    2921 pesos
#
#
#                    199 pesos con 43 centavos
#
#
#                    50876 pesos
#
#
#                    42845 pesos
#
#
#               Celular Zte Blade A31 Negro 1gb Ram 32gb Rom
#
#
#               Samsung Galaxy Z Fold3 5g 256gb + 12gb Negro  Sm-f926bzkaaro
#
#
#               Samsung Galaxy A03 64 Gb 4 Gb Ram Negro
#
#
#               Celular Alcatel 1 Plus 16gb Rom 1gb Ram Volcano Black
#
#
#               Samsung Galaxy A33 5g Awesome Black 128gb Rom 6gb Ram
#
#
#               Celular Samsung Galaxy A03 Core 2gb 32gb Negro Cuotas
#
#
#               Xiaomi Poco F3 5g Dual Sim 128 Gb Negro Nocturno 6 Gb Ram
#
#
#               Celular Xiaomi Redmi 9c Dual Sim 4gb Ram + 128 Gb Purpura Cu
#
#
#               Xiaomi Redmi 10 Dual Sim 128 Gb 4 Gb Ram Carbon Gray Cuotas
#
#
#               Samsung Galaxy A23 128gb + 4gb Ram Black Sm-a235mzkearo
#
#
#               Samsung Galaxy A32 128gb Rom 4gb Ram Awesome White
#
#
#               Motorola G52 Negro 6gb+128gb Pau60016ar
#
#
#               Xiaomi Mi 11 Lite Negro 5g Ne 8gb+256gb
#
#
#               Samsung Galaxy A03 64gb + 4gb Negro
#
#
#               Celular Alcatel 1 Plus 16gb Rom 1gb Ram Volcano Black Cuotas
#
#
#               Celular Samsung Galaxy A03 Core 2gb 32gb Negro
#
#
#               Celular Zte Blade A31 Negro 1gb Ram 32gb Rom
#
#
#               Celular Xiaomi Redmi 9c Dual Sim 4gb Ram + 128 Gb Purpura
#
#
#               Xiaomi Redmi 10 Dual Sim 128 Gb 4 Gb Ram Carbon Gray
#
#
#               Samsung Galaxy Z Fold3 5g 256gb + 12gb Negro Cuotas
#
#
#               Samsung Galaxy A23 128gb + 4gb Ram Black Sm-a235mzkearo
#
#
#               Samsung Galaxy A32 128gb 4gb Ram Awesome White
#
#
#               Xiaomi Poco F3 128gb + 6gb Night Black
#
#
#               Celular Xiaomi Mi 11 Lite Negro 5g Ne 8gb+256gb
#
#
#               Samsung Galaxy A03 3gb 32gb Negro Sm-a035mzkaaro
#
#
#               Samsung Galaxy A03 Core 2gb 32gb Verde Menta Sm-a032mlgaaro
#
#
#               Samsung Galaxy A03 3gb 32gb Azul Sm-a035mzbaaro
#
#
#               Samsung Galaxy A03 Core 2gb 32gb Azul Sm-a032mzbaaro Cuotas
#
#
#               Samsung Galaxy A03 4gb 128gb Negro Sm-a035mzkfaro
#
#
#               Samsung Galaxy A03 Core 2gb 32gb Azul Sm-a032mzbaaro
#
#
#               Samsung Galaxy A03 3gb 32gb Negro Sm-a035mzkaaro
#
#
#               Samsung Galaxy A03 Core 2gb 32gb Verde Menta Sm-a032mlgaaro
#
#
#               Samsung Galaxy A03 4gb 64gb Azul Sm-a035mzbearo
#
#
#               Samsung Galaxy A03 3gb 32gb Azul Sm-a035mzbaaro
#
#
#               Samsung Galaxy A03 Negro 128gb + 4gb Sm-a035mzkfaro
#
#
#               Samsung Galaxy A03 Azul 64gb + 4gb Sm-a035mzbearo
#
#
#               Cable Kolke Usb Para iPhone 6 7 8 Plus Xs Xr 11 Pro Max 1 Mt
#
#
#               Samsung Galaxy A33 128gb + 6gb 5g Awesome Black
#
#
#               Cargador De Pared Tagwood Ichar34 Cuotas
#
#
#               Auriculares Maxell Solid+ Sin-8 Bluetooth Inalambricos
#
#
#               Cable De Datos Apple Doc Usb Ma591
#
#
#               Mercado Pago Point Mini Cobra Desde Tu Celular Cuotas
#
#
#               Cable De Datos Apple Doc Usb Ma591
#
#
#               Funda Para Samsung S3 Candyshell Negro Speck Cuotas
#
#
#               Cargador De Pared Tagwood Ichar34
#
#
#               Mercado Pago Point Mini Cobra Desde Tu Celular
#
#
#               Auriculares Maxell Solid+ Sin-8 Bluetooth Inalambricos
#
#
#               Funda Para Samsung S3 Candyshell Negro Speck
#
#
#               Samsung Galaxy A03 128 Gb 4 Gb Ram Negro Sm-a035mzkfaro
#
#
#               Samsung Galaxy A03 128 Gb 4 Gb Ram Negro Sm-a035mzkfaro

# %%
# remove values with "antes"
pricelistp = [x for x in pricelist if "Antes:" not in x]
print(pricelistp)
# Out:
# ['16628 pesos', '391613 pesos', '39143 pesos', '17493 pesos', '86600 pesos', '37771 pesos', '190265 pesos', '82785 pesos', '112856 pesos', '76132 pesos', '78432 pesos', '68874 pesos', '199540 pesos', '47128 pesos', '20773 pesos', '31807 pesos', '19744 pesos', '69717 pesos', '95210 pesos', '465023 pesos', '90404 pesos', '94118 pesos', '160229 pesos', '168040 pesos', '40484 pesos', '31194 pesos', '36463 pesos', '39758 pesos', '44340 pesos', '33481 pesos', '48074 pesos', '36780 pesos', '43804 pesos', '42522 pesos', '56609 pesos', '52015 pesos', '461 pesos con 86 centavos', '100015 pesos', '3476 pesos', '3468 pesos', '6614 pesos', '402 pesos con 06 centavos', '5571 pesos', '239 pesos con 17 centavos', '2927 pesos', '338 pesos con 66 centavos', '2921 pesos', '199 pesos con 43 centavos', '50876 pesos', '42845 pesos']

# %%
print(len(pricelistp))
print(len(namelist))
# Out:
# 50
# 50

# %%
joindata = list(zip(pricelistp,namelist))
print(joindata)
# Out:
# [('16628 pesos', 'Celular Zte Blade A31 Negro 1gb Ram 32gb Rom'), ('391613 pesos', 'Samsung Galaxy Z Fold3 5g 256gb + 12gb Negro  Sm-f926bzkaaro'), ('39143 pesos', 'Samsung Galaxy A03 64 Gb 4 Gb Ram Negro'), ('17493 pesos', 'Celular Alcatel 1 Plus 16gb Rom 1gb Ram Volcano Black'), ('86600 pesos', 'Samsung Galaxy A33 5g Awesome Black 128gb Rom 6gb Ram'), ('37771 pesos', 'Celular Samsung Galaxy A03 Core 2gb 32gb Negro Cuotas'), ('190265 pesos', 'Xiaomi Poco F3 5g Dual Sim 128 Gb Negro Nocturno 6 Gb Ram'), ('82785 pesos', 'Celular Xiaomi Redmi 9c Dual Sim 4gb Ram + 128 Gb Purpura Cu'), ('112856 pesos', 'Xiaomi Redmi 10 Dual Sim 128 Gb 4 Gb Ram Carbon Gray Cuotas'), ('76132 pesos', 'Samsung Galaxy A23 128gb + 4gb Ram Black Sm-a235mzkearo'), ('78432 pesos', 'Samsung Galaxy A32 128gb Rom 4gb Ram Awesome White'), ('68874 pesos', 'Motorola G52 Negro 6gb+128gb Pau60016ar'), ('199540 pesos', 'Xiaomi Mi 11 Lite Negro 5g Ne 8gb+256gb'), ('47128 pesos', 'Samsung Galaxy A03 64gb + 4gb Negro'), ('20773 pesos', 'Celular Alcatel 1 Plus 16gb Rom 1gb Ram Volcano Black Cuotas'), ('31807 pesos', 'Celular Samsung Galaxy A03 Core 2gb 32gb Negro'), ('19744 pesos', 'Celular Zte Blade A31 Negro 1gb Ram 32gb Rom'), ('69717 pesos', 'Celular Xiaomi Redmi 9c Dual Sim 4gb Ram + 128 Gb Purpura'), ('95210 pesos', 'Xiaomi Redmi 10 Dual Sim 128 Gb 4 Gb Ram Carbon Gray'), ('465023 pesos', 'Samsung Galaxy Z Fold3 5g 256gb + 12gb Negro Cuotas'), ('90404 pesos', 'Samsung Galaxy A23 128gb + 4gb Ram Black Sm-a235mzkearo'), ('94118 pesos', 'Samsung Galaxy A32 128gb 4gb Ram Awesome White'), ('160229 pesos', 'Xiaomi Poco F3 128gb + 6gb Night Black'), ('168040 pesos', 'Celular Xiaomi Mi 11 Lite Negro 5g Ne 8gb+256gb'), ('40484 pesos', 'Samsung Galaxy A03 3gb 32gb Negro Sm-a035mzkaaro'), ('31194 pesos', 'Samsung Galaxy A03 Core 2gb 32gb Verde Menta Sm-a032mlgaaro'), ('36463 pesos', 'Samsung Galaxy A03 3gb 32gb Azul Sm-a035mzbaaro'), ('39758 pesos', 'Samsung Galaxy A03 Core 2gb 32gb Azul Sm-a032mzbaaro Cuotas'), ('44340 pesos', 'Samsung Galaxy A03 4gb 128gb Negro Sm-a035mzkfaro'), ('33481 pesos', 'Samsung Galaxy A03 Core 2gb 32gb Azul Sm-a032mzbaaro'), ('48074 pesos', 'Samsung Galaxy A03 3gb 32gb Negro Sm-a035mzkaaro'), ('36780 pesos', 'Samsung Galaxy A03 Core 2gb 32gb Verde Menta Sm-a032mlgaaro'), ('43804 pesos', 'Samsung Galaxy A03 4gb 64gb Azul Sm-a035mzbearo'), ('42522 pesos', 'Samsung Galaxy A03 3gb 32gb Azul Sm-a035mzbaaro'), ('56609 pesos', 'Samsung Galaxy A03 Negro 128gb + 4gb Sm-a035mzkfaro'), ('52015 pesos', 'Samsung Galaxy A03 Azul 64gb + 4gb Sm-a035mzbearo'), ('461 pesos con 86 centavos', 'Cable Kolke Usb Para iPhone 6 7 8 Plus Xs Xr 11 Pro Max 1 Mt'), ('100015 pesos', 'Samsung Galaxy A33 128gb + 6gb 5g Awesome Black'), ('3476 pesos', 'Cargador De Pared Tagwood Ichar34 Cuotas'), ('3468 pesos', 'Auriculares Maxell Solid+ Sin-8 Bluetooth Inalambricos'), ('6614 pesos', 'Cable De Datos Apple Doc Usb Ma591'), ('402 pesos con 06 centavos', 'Mercado Pago Point Mini Cobra Desde Tu Celular Cuotas'), ('5571 pesos', 'Cable De Datos Apple Doc Usb Ma591'), ('239 pesos con 17 centavos', 'Funda Para Samsung S3 Candyshell Negro Speck Cuotas'), ('2927 pesos', 'Cargador De Pared Tagwood Ichar34'), ('338 pesos con 66 centavos', 'Mercado Pago Point Mini Cobra Desde Tu Celular'), ('2921 pesos', 'Auriculares Maxell Solid+ Sin-8 Bluetooth Inalambricos'), ('199 pesos con 43 centavos', 'Funda Para Samsung S3 Candyshell Negro Speck'), ('50876 pesos', 'Samsung Galaxy A03 128 Gb 4 Gb Ram Negro Sm-a035mzkfaro'), ('42845 pesos', 'Samsung Galaxy A03 128 Gb 4 Gb Ram Negro Sm-a035mzkfaro')]

# %%
# export data to csv

import csv
fields = ['product','price']
rows = joindata

with open ('ArgColorCelulares.csv', 'w', newline='') as f:
    write = csv.writer(f)
    write.writerow(fields)
    write.writerows(rows)
