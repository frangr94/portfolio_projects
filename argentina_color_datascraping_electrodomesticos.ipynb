# %%
import pandas as pd
from bs4 import BeautifulSoup
import smtplib
import requests
import time
import datetime

# %%
# celulares

URL = "https://www.argentinacolor.com/electrodomesticos"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"}
page = requests.get(URL,headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
prices = soup2.find_all('span', attrs={'class':'price-tag-text-sr-only'})
names = soup2.find_all('h2', attrs={'class':'ui-search-item__title'})
print(prices)
print(names)
# Out:
# [<span class="price-tag-text-sr-only">
#                    9296 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    10496 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    8359 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11889 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    7389 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    17705 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12464 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9598 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12121 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    40655 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    8773 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11039 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    16006 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    8815 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    2295 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    27218 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    13722 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9999 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    4846 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11573 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    5755 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    1933 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11245 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    6848 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    4536 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    7168 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    22361 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    10687 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    14394 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12582 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9758 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    8999 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    10771 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    6126 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    22398 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    37662 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    7703 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    17881 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9879 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    8233 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11756 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    10005 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9981 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12840 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    18736 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    14940 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11977 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11727 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    6310 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9598 pesos
#                   </span>]
# [<h2 class="ui-search-item__title">
#               Batidora Manual Liliana Vuelty 450w Ab101
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Eléctrica Philips 1.7l Hd9368/90
#              </h2>, <h2 class="ui-search-item__title">
#               Plancha A Vapor Black+decker Acero Inoxidable Ir7003-ar
#              </h2>, <h2 class="ui-search-item__title">
#               Batidora De Pie Black+decker Mx1003 500w Blanca 220v/240v
#              </h2>, <h2 class="ui-search-item__title">
#               Sodastream Fizzi Maquina Para Soda + Botella Co2
#              </h2>, <h2 class="ui-search-item__title">
#               Mixer Liliana 0,9lts Supermix 800w Negro Ah730
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Eléctrica Philips 1.7l Hd9368/90
#              </h2>, <h2 class="ui-search-item__title">
#               Jarra Eléctrica Peabody Digital Pe-k1708
#              </h2>, <h2 class="ui-search-item__title">
#               Minipimer 2 Velocidades Black+decker 500w Hb1003-wc
#              </h2>, <h2 class="ui-search-item__title">
#               Aspiradora Ultracomb Tambor 24 Lts. 1400w As-4310
#              </h2>, <h2 class="ui-search-item__title">
#               Sodastream Fizzi Maquina Para Soda + Botella Co2
#              </h2>, <h2 class="ui-search-item__title">
#               Batidora Manual Liliana Vuelty 450w Ab101
#              </h2>, <h2 class="ui-search-item__title">
#               Vaporera Eléctrica Ultracomb 900w Vp-4603
#              </h2>, <h2 class="ui-search-item__title">
#               Licuadora Ultracomb Portátil Mixer To Go Lc-2203c
#              </h2>, <h2 class="ui-search-item__title">
#               Botella Sodastream 1lt Gasificadora
#              </h2>, <h2 class="ui-search-item__title">
#               Batidora Liliana Planetaria Ab914n
#              </h2>, <h2 class="ui-search-item__title">
#               Fabrica Algodon De Azucar Ultracomb Fa-2900 900w
#              </h2>, <h2 class="ui-search-item__title">
#               Plancha Philips Vapor Gc1022/40 Base Antiadherente
#              </h2>, <h2 class="ui-search-item__title">
#               Exprimidor De Cítricos Oster Fpstju407b
#              </h2>, <h2 class="ui-search-item__title">
#               Procesadora Philips Blanca Powerchop 600w Hr7615/00
#              </h2>, <h2 class="ui-search-item__title">
#               Exprimidor De Cítricos Oster Fpstju407b Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Botella Sodastream 1lt Gasificadora
#              </h2>, <h2 class="ui-search-item__title">
#               Tostadora Philips 900w 8 Niveles Hd2581/00
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Eléctrica Ultracomb 1.7 Lts. 2200w Pe-4909
#              </h2>, <h2 class="ui-search-item__title">
#               Exprimidor Electrico Liliana Citrijug Ae920
#              </h2>, <h2 class="ui-search-item__title">
#               Batidora Manual Liliana Shake 450w Ab103
#              </h2>, <h2 class="ui-search-item__title">
#               Aspiradora Yelmo Con Bolsa As-3210 2.5 Lts
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Electrica Oster Con Regulador Kt4970w Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Minipimer 2 Velocidades Black+decker 500w Hb1003-wc
#              </h2>, <h2 class="ui-search-item__title">
#               Yogurtera Ultracomb 2.5 Lts. 12 Frascos Yg-2712
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Eléctrica Oster Negra Bvstkt4970 220v 1.7l
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Electrica Oster Con Regulador Kt4970w
#              </h2>, <h2 class="ui-search-item__title">
#               Exprimidor Liliana Pico Acero Inox 100w Ae930
#              </h2>, <h2 class="ui-search-item__title">
#               Tostadora Ultracomb Automática 750w To-4005
#              </h2>, <h2 class="ui-search-item__title">
#               E-termo Peabody 1 Lts. 2 Temperaturas Pe-et1000s
#              </h2>, <h2 class="ui-search-item__title">
#               Aspiradora Ultracomb Robot 300 Ml 6w As-6060
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Eléctrica Yelmo 1850w 1.7lts Pe-3902k
#              </h2>, <h2 class="ui-search-item__title">
#               Multiprocesadora Liliana Megapros 740w Blanco Am740
#              </h2>, <h2 class="ui-search-item__title">
#               Exprimidor De Cítricos Peabody Rojo 100w Pe-ec402r
#              </h2>, <h2 class="ui-search-item__title">
#               Molinillo Eléctrico Ultracomb Para Café Mo-8100a
#              </h2>, <h2 class="ui-search-item__title">
#               Licuadora De Mano Electrolux Iba10 500w 2 Velocidades
#              </h2>, <h2 class="ui-search-item__title">
#               Pava Electrica Liliana Matera Negra Ap-165
#              </h2>, <h2 class="ui-search-item__title">
#               Procesadora Manual Liliana Rainbow Mix 450w Blanco Ah101b
#              </h2>, <h2 class="ui-search-item__title">
#               Licuadora Yelmo Jarra De Vidrio 700w 1.5 Litros Lc1010
#              </h2>, <h2 class="ui-search-item__title">
#               Planchita A Vapor Philips Gris 2400w Dst5010/10
#              </h2>, <h2 class="ui-search-item__title">
#               Yogurtera Ultracomb 2.5 Lts. 12 Frascos Yg-2712
#              </h2>, <h2 class="ui-search-item__title">
#               Procesadora Manual Liliana Rainbow Mix 450w Blanco Ah101b
#              </h2>, <h2 class="ui-search-item__title">
#               Sandwichera Eléctrica Ultracomb 3 En 1 Sw-2801
#              </h2>, <h2 class="ui-search-item__title">
#               Exprimidor Philips 25w Verde Hr2738/00
#              </h2>, <h2 class="ui-search-item__title">
#               Waflera Peabody 1000w Negra Pe-wm186
#              </h2>]

# %%
# get price list and name list
pricelist=[]
for span in prices:
    print(span.string)
    pricelist.append(span.string.strip())

namelist=[]
for h2 in names:
    print(h2.string)
    namelist.append(h2.string.strip())
# Out:
#                    9296 pesos
#
#
#                    10496 pesos
#
#
#                    8359 pesos
#
#
#                    11889 pesos
#
#
#                    7389 pesos
#
#
#                    17705 pesos
#
#
#                    12464 pesos
#
#
#                    9598 pesos
#
#
#                    12121 pesos
#
#
#                    40655 pesos
#
#
#                    8773 pesos
#
#
#                    11039 pesos
#
#
#                    16006 pesos
#
#
#                    8815 pesos
#
#
#                    2295 pesos
#
#
#                    27218 pesos
#
#
#                    13722 pesos
#
#
#                    9999 pesos
#
#
#                    4846 pesos
#
#
#                    11573 pesos
#
#
#                    5755 pesos
#
#
#                    1933 pesos
#
#
#                    11245 pesos
#
#
#                    6848 pesos
#
#
#                    4536 pesos
#
#
#                    7168 pesos
#
#
#                    22361 pesos
#
#
#                    10687 pesos
#
#
#                    14394 pesos
#
#
#                    12582 pesos
#
#
#                    9758 pesos
#
#
#                    8999 pesos
#
#
#                    10771 pesos
#
#
#                    6126 pesos
#
#
#                    22398 pesos
#
#
#                    37662 pesos
#
#
#                    7703 pesos
#
#
#                    17881 pesos
#
#
#                    9879 pesos
#
#
#                    8233 pesos
#
#
#                    11756 pesos
#
#
#                    10005 pesos
#
#
#                    9981 pesos
#
#
#                    12840 pesos
#
#
#                    18736 pesos
#
#
#                    14940 pesos
#
#
#                    11977 pesos
#
#
#                    11727 pesos
#
#
#                    6310 pesos
#
#
#                    9598 pesos
#
#
#               Batidora Manual Liliana Vuelty 450w Ab101
#
#
#               Pava Eléctrica Philips 1.7l Hd9368/90
#
#
#               Plancha A Vapor Black+decker Acero Inoxidable Ir7003-ar
#
#
#               Batidora De Pie Black+decker Mx1003 500w Blanca 220v/240v
#
#
#               Sodastream Fizzi Maquina Para Soda + Botella Co2
#
#
#               Mixer Liliana 0,9lts Supermix 800w Negro Ah730
#
#
#               Pava Eléctrica Philips 1.7l Hd9368/90
#
#
#               Jarra Eléctrica Peabody Digital Pe-k1708
#
#
#               Minipimer 2 Velocidades Black+decker 500w Hb1003-wc
#
#
#               Aspiradora Ultracomb Tambor 24 Lts. 1400w As-4310
#
#
#               Sodastream Fizzi Maquina Para Soda + Botella Co2
#
#
#               Batidora Manual Liliana Vuelty 450w Ab101
#
#
#               Vaporera Eléctrica Ultracomb 900w Vp-4603
#
#
#               Licuadora Ultracomb Portátil Mixer To Go Lc-2203c
#
#
#               Botella Sodastream 1lt Gasificadora
#
#
#               Batidora Liliana Planetaria Ab914n
#
#
#               Fabrica Algodon De Azucar Ultracomb Fa-2900 900w
#
#
#               Plancha Philips Vapor Gc1022/40 Base Antiadherente
#
#
#               Exprimidor De Cítricos Oster Fpstju407b
#
#
#               Procesadora Philips Blanca Powerchop 600w Hr7615/00
#
#
#               Exprimidor De Cítricos Oster Fpstju407b Cuotas
#
#
#               Botella Sodastream 1lt Gasificadora
#
#
#               Tostadora Philips 900w 8 Niveles Hd2581/00
#
#
#               Pava Eléctrica Ultracomb 1.7 Lts. 2200w Pe-4909
#
#
#               Exprimidor Electrico Liliana Citrijug Ae920
#
#
#               Batidora Manual Liliana Shake 450w Ab103
#
#
#               Aspiradora Yelmo Con Bolsa As-3210 2.5 Lts
#
#
#               Pava Electrica Oster Con Regulador Kt4970w Cuotas
#
#
#               Minipimer 2 Velocidades Black+decker 500w Hb1003-wc
#
#
#               Yogurtera Ultracomb 2.5 Lts. 12 Frascos Yg-2712
#
#
#               Pava Eléctrica Oster Negra Bvstkt4970 220v 1.7l
#
#
#               Pava Electrica Oster Con Regulador Kt4970w
#
#
#               Exprimidor Liliana Pico Acero Inox 100w Ae930
#
#
#               Tostadora Ultracomb Automática 750w To-4005
#
#
#               E-termo Peabody 1 Lts. 2 Temperaturas Pe-et1000s
#
#
#               Aspiradora Ultracomb Robot 300 Ml 6w As-6060
#
#
#               Pava Eléctrica Yelmo 1850w 1.7lts Pe-3902k
#
#
#               Multiprocesadora Liliana Megapros 740w Blanco Am740
#
#
#               Exprimidor De Cítricos Peabody Rojo 100w Pe-ec402r
#
#
#               Molinillo Eléctrico Ultracomb Para Café Mo-8100a
#
#
#               Licuadora De Mano Electrolux Iba10 500w 2 Velocidades
#
#
#               Pava Electrica Liliana Matera Negra Ap-165
#
#
#               Procesadora Manual Liliana Rainbow Mix 450w Blanco Ah101b
#
#
#               Licuadora Yelmo Jarra De Vidrio 700w 1.5 Litros Lc1010
#
#
#               Planchita A Vapor Philips Gris 2400w Dst5010/10
#
#
#               Yogurtera Ultracomb 2.5 Lts. 12 Frascos Yg-2712
#
#
#               Procesadora Manual Liliana Rainbow Mix 450w Blanco Ah101b
#
#
#               Sandwichera Eléctrica Ultracomb 3 En 1 Sw-2801
#
#
#               Exprimidor Philips 25w Verde Hr2738/00
#
#
#               Waflera Peabody 1000w Negra Pe-wm186

# %%
# remove values with "antes"
pricelistp = [x for x in pricelist if "Antes:" not in x]
print(pricelistp)
# Out:
# ['9296 pesos', '10496 pesos', '8359 pesos', '11889 pesos', '7389 pesos', '17705 pesos', '12464 pesos', '9598 pesos', '12121 pesos', '40655 pesos', '8773 pesos', '11039 pesos', '16006 pesos', '8815 pesos', '2295 pesos', '27218 pesos', '13722 pesos', '9999 pesos', '4846 pesos', '11573 pesos', '5755 pesos', '1933 pesos', '11245 pesos', '6848 pesos', '4536 pesos', '7168 pesos', '22361 pesos', '10687 pesos', '14394 pesos', '12582 pesos', '9758 pesos', '8999 pesos', '10771 pesos', '6126 pesos', '22398 pesos', '37662 pesos', '7703 pesos', '17881 pesos', '9879 pesos', '8233 pesos', '11756 pesos', '10005 pesos', '9981 pesos', '12840 pesos', '18736 pesos', '14940 pesos', '11977 pesos', '11727 pesos', '6310 pesos', '9598 pesos']

# %%
print(len(pricelistp))
print(len(namelist))
# Out:
# 50
# 50

# %%
joindata = list(zip(pricelistp,namelist))
print(joindata)
# Out:
# [('9296 pesos', 'Batidora Manual Liliana Vuelty 450w Ab101'), ('10496 pesos', 'Pava Eléctrica Philips 1.7l Hd9368/90'), ('8359 pesos', 'Plancha A Vapor Black+decker Acero Inoxidable Ir7003-ar'), ('11889 pesos', 'Batidora De Pie Black+decker Mx1003 500w Blanca 220v/240v'), ('7389 pesos', 'Sodastream Fizzi Maquina Para Soda + Botella Co2'), ('17705 pesos', 'Mixer Liliana 0,9lts Supermix 800w Negro Ah730'), ('12464 pesos', 'Pava Eléctrica Philips 1.7l Hd9368/90'), ('9598 pesos', 'Jarra Eléctrica Peabody Digital Pe-k1708'), ('12121 pesos', 'Minipimer 2 Velocidades Black+decker 500w Hb1003-wc'), ('40655 pesos', 'Aspiradora Ultracomb Tambor 24 Lts. 1400w As-4310'), ('8773 pesos', 'Sodastream Fizzi Maquina Para Soda + Botella Co2'), ('11039 pesos', 'Batidora Manual Liliana Vuelty 450w Ab101'), ('16006 pesos', 'Vaporera Eléctrica Ultracomb 900w Vp-4603'), ('8815 pesos', 'Licuadora Ultracomb Portátil Mixer To Go Lc-2203c'), ('2295 pesos', 'Botella Sodastream 1lt Gasificadora'), ('27218 pesos', 'Batidora Liliana Planetaria Ab914n'), ('13722 pesos', 'Fabrica Algodon De Azucar Ultracomb Fa-2900 900w'), ('9999 pesos', 'Plancha Philips Vapor Gc1022/40 Base Antiadherente'), ('4846 pesos', 'Exprimidor De Cítricos Oster Fpstju407b'), ('11573 pesos', 'Procesadora Philips Blanca Powerchop 600w Hr7615/00'), ('5755 pesos', 'Exprimidor De Cítricos Oster Fpstju407b Cuotas'), ('1933 pesos', 'Botella Sodastream 1lt Gasificadora'), ('11245 pesos', 'Tostadora Philips 900w 8 Niveles Hd2581/00'), ('6848 pesos', 'Pava Eléctrica Ultracomb 1.7 Lts. 2200w Pe-4909'), ('4536 pesos', 'Exprimidor Electrico Liliana Citrijug Ae920'), ('7168 pesos', 'Batidora Manual Liliana Shake 450w Ab103'), ('22361 pesos', 'Aspiradora Yelmo Con Bolsa As-3210 2.5 Lts'), ('10687 pesos', 'Pava Electrica Oster Con Regulador Kt4970w Cuotas'), ('14394 pesos', 'Minipimer 2 Velocidades Black+decker 500w Hb1003-wc'), ('12582 pesos', 'Yogurtera Ultracomb 2.5 Lts. 12 Frascos Yg-2712'), ('9758 pesos', 'Pava Eléctrica Oster Negra Bvstkt4970 220v 1.7l'), ('8999 pesos', 'Pava Electrica Oster Con Regulador Kt4970w'), ('10771 pesos', 'Exprimidor Liliana Pico Acero Inox 100w Ae930'), ('6126 pesos', 'Tostadora Ultracomb Automática 750w To-4005'), ('22398 pesos', 'E-termo Peabody 1 Lts. 2 Temperaturas Pe-et1000s'), ('37662 pesos', 'Aspiradora Ultracomb Robot 300 Ml 6w As-6060'), ('7703 pesos', 'Pava Eléctrica Yelmo 1850w 1.7lts Pe-3902k'), ('17881 pesos', 'Multiprocesadora Liliana Megapros 740w Blanco Am740'), ('9879 pesos', 'Exprimidor De Cítricos Peabody Rojo 100w Pe-ec402r'), ('8233 pesos', 'Molinillo Eléctrico Ultracomb Para Café Mo-8100a'), ('11756 pesos', 'Licuadora De Mano Electrolux Iba10 500w 2 Velocidades'), ('10005 pesos', 'Pava Electrica Liliana Matera Negra Ap-165'), ('9981 pesos', 'Procesadora Manual Liliana Rainbow Mix 450w Blanco Ah101b'), ('12840 pesos', 'Licuadora Yelmo Jarra De Vidrio 700w 1.5 Litros Lc1010'), ('18736 pesos', 'Planchita A Vapor Philips Gris 2400w Dst5010/10'), ('14940 pesos', 'Yogurtera Ultracomb 2.5 Lts. 12 Frascos Yg-2712'), ('11977 pesos', 'Procesadora Manual Liliana Rainbow Mix 450w Blanco Ah101b'), ('11727 pesos', 'Sandwichera Eléctrica Ultracomb 3 En 1 Sw-2801'), ('6310 pesos', 'Exprimidor Philips 25w Verde Hr2738/00'), ('9598 pesos', 'Waflera Peabody 1000w Negra Pe-wm186')]

# %%
# export data to csv

import csv
fields = ['product','price']
rows = joindata

with open ('ArgColorElectro.csv', 'w', newline='') as f:
    write = csv.writer(f)
    write.writerow(fields)
    write.writerows(rows)
