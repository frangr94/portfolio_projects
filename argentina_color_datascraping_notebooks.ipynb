# %%
import pandas as pd
from bs4 import BeautifulSoup
import smtplib
import requests
import time
import datetime

# %%
# celulares

URL = "https://www.argentinacolor.com/listado/computacion/laptops-accesorios/notebooks/notebooks"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"}
page = requests.get(URL,headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
prices = soup2.find_all('span', attrs={'class':'price-tag-text-sr-only'})
names = soup2.find_all('h2', attrs={'class':'ui-search-item__title'})
print(prices)
print(names)
# Out:
# [<span class="price-tag-text-sr-only">
#                   Antes: 79819 pesos con 01 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    75828 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    333631 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 72562 pesos con 21 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    61678 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    275801 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 86164 pesos con 30 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    73240 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    160638 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    90043 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    135279 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    232262 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    237218 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    181336 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 210284 pesos con 90 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    199771 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    152710 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 126869 pesos con 79 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    120526 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                   Antes: 150652 pesos con 44 centavos
#                  </span>, <span class="price-tag-text-sr-only">
#                    143120 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    280963 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    298078 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    251022 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    165814 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    196897 pesos
#                   </span>]
# [<h2 class="ui-search-item__title">
#               Notebook Innjoo Voom Max 6gb 64gb Ssd 256gb Sd W10h Negro
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Hp Probook 450 G8 15.6  I5-1135g7 8gb 256ssd W10p
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Innjoo Voom Max 14fhd/celeron N3350/6gb/64ssd/128gb
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Lenovo Thinkpad E15 I5 8gb 256ssd Fdos 20tes2ga00
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Innjoo Voom Max 14fhd/celeron N3350/6gb/64ssd/128gb
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Lenovo V15 15,6  I3 8gb 1tb Free Dos Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Innjoo Voom Max 6gb 64gb Ssd 256gb Sd W10h Negro
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Lenovo V15 I3 8gb 1tb 15,6  Free Dos 82nb002far
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Lenovo Thinkpad E15 I5 8gb 256ssd Fdos 20tes2ga00
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Dell Vostro 3400 14hd/i5-1135g7/8gb/256ssd/w10p
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Enova I5 1035g1 8gb Ram 240gb
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Dell Vostro 3400 14hd/i5-1135g7/8gb/256ssd/w10p
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Enova I5 1035g1 8gb Ram 240gb
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Acer Aspire 5 I3 4gb 256gb Freedos Nx.hn2al.011
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Acer Aspire 5 I3 4gb 256gb Freedos Nx.hn2al.011 Cuo
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Hp Probook 450 G8 15.6  I5-1135g7 8gb 256ssd W10p
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Thinkpad Lenovo 8gb Ddr4 I7 Ssd 256gb 15.6 Pulgadas
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Thinkpad Lenovo 8gb Ddr4 I7 Ssd 256gb 15.6 Pulgadas
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Lenovo V15 Iil I7 15.6 8gb 256gb Ssd Win10h 64
#              </h2>, <h2 class="ui-search-item__title">
#               Notebook Lenovo V15 Iil I7 15.6 8gb 256gb Ssd Win10h 64
#              </h2>]

# %%
# get price list and name list
pricelist=[]
for span in prices:
    print(span.string)
    pricelist.append(span.string.strip())

namelist=[]
for h2 in names:
    print(h2.string)
    namelist.append(h2.string.strip())
# Out:
#                   Antes: 79819 pesos con 01 centavos
#
#
#                    75828 pesos
#
#
#                    333631 pesos
#
#
#                   Antes: 72562 pesos con 21 centavos
#
#
#                    61678 pesos
#
#
#                    275801 pesos
#
#
#                   Antes: 86164 pesos con 30 centavos
#
#
#                    73240 pesos
#
#
#                    160638 pesos
#
#
#                    90043 pesos
#
#
#                    135279 pesos
#
#
#                    232262 pesos
#
#
#                    237218 pesos
#
#
#                    181336 pesos
#
#
#                   Antes: 210284 pesos con 90 centavos
#
#
#                    199771 pesos
#
#
#                    152710 pesos
#
#
#                   Antes: 126869 pesos con 79 centavos
#
#
#                    120526 pesos
#
#
#                   Antes: 150652 pesos con 44 centavos
#
#
#                    143120 pesos
#
#
#                    280963 pesos
#
#
#                    298078 pesos
#
#
#                    251022 pesos
#
#
#                    165814 pesos
#
#
#                    196897 pesos
#
#
#               Notebook Innjoo Voom Max 6gb 64gb Ssd 256gb Sd W10h Negro
#
#
#               Notebook Hp Probook 450 G8 15.6  I5-1135g7 8gb 256ssd W10p
#
#
#               Notebook Innjoo Voom Max 14fhd/celeron N3350/6gb/64ssd/128gb
#
#
#               Notebook Lenovo Thinkpad E15 I5 8gb 256ssd Fdos 20tes2ga00
#
#
#               Notebook Innjoo Voom Max 14fhd/celeron N3350/6gb/64ssd/128gb
#
#
#               Notebook Lenovo V15 15,6  I3 8gb 1tb Free Dos Cuotas
#
#
#               Notebook Innjoo Voom Max 6gb 64gb Ssd 256gb Sd W10h Negro
#
#
#               Notebook Lenovo V15 I3 8gb 1tb 15,6  Free Dos 82nb002far
#
#
#               Notebook Lenovo Thinkpad E15 I5 8gb 256ssd Fdos 20tes2ga00
#
#
#               Notebook Dell Vostro 3400 14hd/i5-1135g7/8gb/256ssd/w10p
#
#
#               Notebook Enova I5 1035g1 8gb Ram 240gb
#
#
#               Notebook Dell Vostro 3400 14hd/i5-1135g7/8gb/256ssd/w10p
#
#
#               Notebook Enova I5 1035g1 8gb Ram 240gb
#
#
#               Notebook Acer Aspire 5 I3 4gb 256gb Freedos Nx.hn2al.011
#
#
#               Notebook Acer Aspire 5 I3 4gb 256gb Freedos Nx.hn2al.011 Cuo
#
#
#               Notebook Hp Probook 450 G8 15.6  I5-1135g7 8gb 256ssd W10p
#
#
#               Notebook Thinkpad Lenovo 8gb Ddr4 I7 Ssd 256gb 15.6 Pulgadas
#
#
#               Notebook Thinkpad Lenovo 8gb Ddr4 I7 Ssd 256gb 15.6 Pulgadas
#
#
#               Notebook Lenovo V15 Iil I7 15.6 8gb 256gb Ssd Win10h 64
#
#
#               Notebook Lenovo V15 Iil I7 15.6 8gb 256gb Ssd Win10h 64

# %%
# remove values with "antes"
pricelistp = [x for x in pricelist if "Antes:" not in x]
print(pricelistp)
# Out:
# ['75828 pesos', '333631 pesos', '61678 pesos', '275801 pesos', '73240 pesos', '160638 pesos', '90043 pesos', '135279 pesos', '232262 pesos', '237218 pesos', '181336 pesos', '199771 pesos', '152710 pesos', '120526 pesos', '143120 pesos', '280963 pesos', '298078 pesos', '251022 pesos', '165814 pesos', '196897 pesos']

# %%
print(len(pricelistp))
print(len(namelist))
# Out:
# 20
# 20

# %%
joindata = list(zip(pricelistp,namelist))
print(joindata)
# Out:
# [('75828 pesos', 'Notebook Innjoo Voom Max 6gb 64gb Ssd 256gb Sd W10h Negro'), ('333631 pesos', 'Notebook Hp Probook 450 G8 15.6  I5-1135g7 8gb 256ssd W10p'), ('61678 pesos', 'Notebook Innjoo Voom Max 14fhd/celeron N3350/6gb/64ssd/128gb'), ('275801 pesos', 'Notebook Lenovo Thinkpad E15 I5 8gb 256ssd Fdos 20tes2ga00'), ('73240 pesos', 'Notebook Innjoo Voom Max 14fhd/celeron N3350/6gb/64ssd/128gb'), ('160638 pesos', 'Notebook Lenovo V15 15,6  I3 8gb 1tb Free Dos Cuotas'), ('90043 pesos', 'Notebook Innjoo Voom Max 6gb 64gb Ssd 256gb Sd W10h Negro'), ('135279 pesos', 'Notebook Lenovo V15 I3 8gb 1tb 15,6  Free Dos 82nb002far'), ('232262 pesos', 'Notebook Lenovo Thinkpad E15 I5 8gb 256ssd Fdos 20tes2ga00'), ('237218 pesos', 'Notebook Dell Vostro 3400 14hd/i5-1135g7/8gb/256ssd/w10p'), ('181336 pesos', 'Notebook Enova I5 1035g1 8gb Ram 240gb'), ('199771 pesos', 'Notebook Dell Vostro 3400 14hd/i5-1135g7/8gb/256ssd/w10p'), ('152710 pesos', 'Notebook Enova I5 1035g1 8gb Ram 240gb'), ('120526 pesos', 'Notebook Acer Aspire 5 I3 4gb 256gb Freedos Nx.hn2al.011'), ('143120 pesos', 'Notebook Acer Aspire 5 I3 4gb 256gb Freedos Nx.hn2al.011 Cuo'), ('280963 pesos', 'Notebook Hp Probook 450 G8 15.6  I5-1135g7 8gb 256ssd W10p'), ('298078 pesos', 'Notebook Thinkpad Lenovo 8gb Ddr4 I7 Ssd 256gb 15.6 Pulgadas'), ('251022 pesos', 'Notebook Thinkpad Lenovo 8gb Ddr4 I7 Ssd 256gb 15.6 Pulgadas'), ('165814 pesos', 'Notebook Lenovo V15 Iil I7 15.6 8gb 256gb Ssd Win10h 64'), ('196897 pesos', 'Notebook Lenovo V15 Iil I7 15.6 8gb 256gb Ssd Win10h 64')]

# %%
# export data to csv

import csv
fields = ['product','price']
rows = joindata

with open ('ArgColorNotebooks.csv', 'w', newline='') as f:
    write = csv.writer(f)
    write.writerow(fields)
    write.writerows(rows)
