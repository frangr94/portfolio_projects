# %%
import pandas as pd
from bs4 import BeautifulSoup
import smtplib
import requests
import time
import datetime

# %%
# celulares

URL = "https://www.argentinacolor.com/impresion"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0"}
page = requests.get(URL,headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
prices = soup2.find_all('span', attrs={'class':'price-tag-text-sr-only'})
names = soup2.find_all('h2', attrs={'class':'ui-search-item__title'})
print(prices)
print(names)
# Out:
# [<span class="price-tag-text-sr-only">
#                    194741 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    90278 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    313268 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    102326 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    581376 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    6096 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    233689 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    222573 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11203 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    62970 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    18105 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    13720 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    185628 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    3130 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    36329 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    95220 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    11368 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    3130 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    122427 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    10216 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    6137 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    16165 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    3181 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    71768 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    146912 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    2977 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    10348 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    214545 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    5976 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12423 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    15515 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    77920 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    58014 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    19340 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    178787 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    15425 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    2487 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    121506 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    13889 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12128 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    334302 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    3442 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    9721 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    75231 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    4241 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    3789 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    19398 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    15425 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    12116 pesos
#                   </span>, <span class="price-tag-text-sr-only">
#                    111729 pesos
#                   </span>]
# [<h2 class="ui-search-item__title">
#               Impresora Plotter Hp Designjet T250 24 Pulgadas 61cm Wifi
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Brother Multifuncion Dcp-t420w Color Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Plotter Hp Studio 24 Designjet 24 Pulgadas 5hb12a
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Epson L6490 Ecotank Color Multifuncional A4 Con W
#              </h2>, <h2 class="ui-search-item__title">
#               Plotter Hp Studio 24 Designjet 24 Pulgadas 5hb12a
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 664 Negro + Color Combo 2675 2135 3635 3775 4675
#              </h2>, <h2 class="ui-search-item__title">
#               Plotter Hp Designjet T250 24 Pulgadas (5hb06a) Cuo
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Epson Ecotank L8160 Wi-fi Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 954xl Negro Original L0s71al 7740 8210 8710 8720
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Brother Dcp-1212w Monocromatica Wi-fi Negra Cuo
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 82 Negro Original Ch565a Designjet Hp 510 111
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp W1105a 105a Negro Original M107w 107a M135 M137
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Epson Ecotank L8160 Wi-fi
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 664 Negro F6v29al Orig. 2675 2135 3635 3775 4675
#              </h2>, <h2 class="ui-search-item__title">
#               Combo Hp 950xl Negro + Hp 951xl Colores 8600 8620 8610
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Hp Smart Tank 750 Mfp Wi-fi 6uu47a Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 950xl Negro Original Cn045al Hp 8100 8600 8610
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 662 Negro O Tricolor X Unid. 1515 2515 2545 3545
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Brother Dcp-t720dw Wifi Usb
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 964xl Negro Original 3ja56a Officejet 9020 9010
#              </h2>, <h2 class="ui-search-item__title">
#               Hp 662 Negro + 662 Tricolor Original 1515 2515 2545 Combo
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Hp Multifuncion 2375 Deskjet Ink Advantage Via Usb
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 667 Negro Original 3ym79al Hp Deskjet  2775
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp 147x W1470x High Yield Negro 25200 Copias M610
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Brother Dcp-t720dw Wifi Usb Cuotas
#              </h2>, <h2 class="ui-search-item__title">
#               Tinta Epson T673 Amarillo Original L805 L810 L850 L1800
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 711 Cyan Magenta Amarillo Original Hp T120 T130
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Laser Color Hp M479fdw W1a80a/l Wifi D/f Red Cuot
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 951 Cyan Magenta Yellow 8600 8620 8610
#              </h2>, <h2 class="ui-search-item__title">
#               Cartuchos Hp 60 Negro + Color Original - D110a F4280 F4480
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp Cf513a Magenta Original Hp 204a Laserjet Hp M180nw
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Ricoh P311 Monocromática 408525t + Toner Ricoh
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp Cf237a Negro Original 37a M607 M608 M609 M631 M632
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp Cf217a Negro Original 17a -  M102w M130fw M134a
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Laser Color Hp M479fdw W1a80a/l Wifi D/f Red Full
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp W2311a Cian Original M182 M183 M155 Hp 215a
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Epson T206 Negro Colores Xp2101 Original Individual
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Epson L6490 Ecotank Color Multifuncional A4 Con W
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 662xl Negro + Color Original 1515 2515 2545 3545
#              </h2>, <h2 class="ui-search-item__title">
#               Cabezal Hp 11 C4810a C4811a C4812a C4813a Original Hp 500 10
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Multifuncion Brother Mfc T4500dw A3 Color Doble Fa
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 964 Cian Magenta Amarillo Original Por Unidad
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 122xl Negro Ori Ch563hl 1000 1050 2000 2050 3050
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Brother Multifuncion Dcp-t420w Color
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Epson T140 T140220 T140320 T140420 Original Unidad
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 675 Negro Original Cn690al 4000 4400 4575
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Hp Multifuncion 2375 Deskjet Ink Advantage Via Usb
#              </h2>, <h2 class="ui-search-item__title">
#               Toner Hp W2312a Amarillo Original Hp M182 M183 M155 Hp 215a
#              </h2>, <h2 class="ui-search-item__title">
#               Cartucho Hp 74 Negro  + Hp 75 Color Originales Combo Pack 2u
#              </h2>, <h2 class="ui-search-item__title">
#               Impresora Hp Laserjet Pro M454dw Color Wifi Duplex
#              </h2>]

# %%
# get price list and name list
pricelist=[]
for span in prices:
    print(span.string)
    pricelist.append(span.string.strip())

namelist=[]
for h2 in names:
    print(h2.string)
    namelist.append(h2.string.strip())
# Out:
#                    194741 pesos
#
#
#                    90278 pesos
#
#
#                    313268 pesos
#
#
#                    102326 pesos
#
#
#                    581376 pesos
#
#
#                    6096 pesos
#
#
#                    233689 pesos
#
#
#                    222573 pesos
#
#
#                    11203 pesos
#
#
#                    62970 pesos
#
#
#                    18105 pesos
#
#
#                    13720 pesos
#
#
#                    185628 pesos
#
#
#                    3130 pesos
#
#
#                    36329 pesos
#
#
#                    95220 pesos
#
#
#                    11368 pesos
#
#
#                    3130 pesos
#
#
#                    122427 pesos
#
#
#                    10216 pesos
#
#
#                    6137 pesos
#
#
#                    16165 pesos
#
#
#                    3181 pesos
#
#
#                    71768 pesos
#
#
#                    146912 pesos
#
#
#                    2977 pesos
#
#
#                    10348 pesos
#
#
#                    214545 pesos
#
#
#                    5976 pesos
#
#
#                    12423 pesos
#
#
#                    15515 pesos
#
#
#                    77920 pesos
#
#
#                    58014 pesos
#
#
#                    19340 pesos
#
#
#                    178787 pesos
#
#
#                    15425 pesos
#
#
#                    2487 pesos
#
#
#                    121506 pesos
#
#
#                    13889 pesos
#
#
#                    12128 pesos
#
#
#                    334302 pesos
#
#
#                    3442 pesos
#
#
#                    9721 pesos
#
#
#                    75231 pesos
#
#
#                    4241 pesos
#
#
#                    3789 pesos
#
#
#                    19398 pesos
#
#
#                    15425 pesos
#
#
#                    12116 pesos
#
#
#                    111729 pesos
#
#
#               Impresora Plotter Hp Designjet T250 24 Pulgadas 61cm Wifi
#
#
#               Impresora Brother Multifuncion Dcp-t420w Color Cuotas
#
#
#               Plotter Hp Studio 24 Designjet 24 Pulgadas 5hb12a
#
#
#               Impresora Epson L6490 Ecotank Color Multifuncional A4 Con W
#
#
#               Plotter Hp Studio 24 Designjet 24 Pulgadas 5hb12a
#
#
#               Cartucho Hp 664 Negro + Color Combo 2675 2135 3635 3775 4675
#
#
#               Plotter Hp Designjet T250 24 Pulgadas (5hb06a) Cuo
#
#
#               Impresora Epson Ecotank L8160 Wi-fi Cuotas
#
#
#               Cartucho Hp 954xl Negro Original L0s71al 7740 8210 8710 8720
#
#
#               Impresora Brother Dcp-1212w Monocromatica Wi-fi Negra Cuo
#
#
#               Cartucho Hp 82 Negro Original Ch565a Designjet Hp 510 111
#
#
#               Toner Hp W1105a 105a Negro Original M107w 107a M135 M137
#
#
#               Impresora Epson Ecotank L8160 Wi-fi
#
#
#               Cartucho Hp 664 Negro F6v29al Orig. 2675 2135 3635 3775 4675
#
#
#               Combo Hp 950xl Negro + Hp 951xl Colores 8600 8620 8610
#
#
#               Impresora Hp Smart Tank 750 Mfp Wi-fi 6uu47a Cuotas
#
#
#               Cartucho Hp 950xl Negro Original Cn045al Hp 8100 8600 8610
#
#
#               Cartucho Hp 662 Negro O Tricolor X Unid. 1515 2515 2545 3545
#
#
#               Impresora Brother Dcp-t720dw Wifi Usb
#
#
#               Cartucho Hp 964xl Negro Original 3ja56a Officejet 9020 9010
#
#
#               Hp 662 Negro + 662 Tricolor Original 1515 2515 2545 Combo
#
#
#               Impresora Hp Multifuncion 2375 Deskjet Ink Advantage Via Usb
#
#
#               Cartucho Hp 667 Negro Original 3ym79al Hp Deskjet  2775
#
#
#               Toner Hp 147x W1470x High Yield Negro 25200 Copias M610
#
#
#               Impresora Brother Dcp-t720dw Wifi Usb Cuotas
#
#
#               Tinta Epson T673 Amarillo Original L805 L810 L850 L1800
#
#
#               Cartucho Hp 711 Cyan Magenta Amarillo Original Hp T120 T130
#
#
#               Impresora Laser Color Hp M479fdw W1a80a/l Wifi D/f Red Cuot
#
#
#               Cartucho Hp 951 Cyan Magenta Yellow 8600 8620 8610
#
#
#               Cartuchos Hp 60 Negro + Color Original - D110a F4280 F4480
#
#
#               Toner Hp Cf513a Magenta Original Hp 204a Laserjet Hp M180nw
#
#
#               Impresora Ricoh P311 Monocromática 408525t + Toner Ricoh
#
#
#               Toner Hp Cf237a Negro Original 37a M607 M608 M609 M631 M632
#
#
#               Toner Hp Cf217a Negro Original 17a -  M102w M130fw M134a
#
#
#               Impresora Laser Color Hp M479fdw W1a80a/l Wifi D/f Red Full
#
#
#               Toner Hp W2311a Cian Original M182 M183 M155 Hp 215a
#
#
#               Cartucho Epson T206 Negro Colores Xp2101 Original Individual
#
#
#               Impresora Epson L6490 Ecotank Color Multifuncional A4 Con W
#
#
#               Cartucho Hp 662xl Negro + Color Original 1515 2515 2545 3545
#
#
#               Cabezal Hp 11 C4810a C4811a C4812a C4813a Original Hp 500 10
#
#
#               Impresora Multifuncion Brother Mfc T4500dw A3 Color Doble Fa
#
#
#               Cartucho Hp 964 Cian Magenta Amarillo Original Por Unidad
#
#
#               Cartucho Hp 122xl Negro Ori Ch563hl 1000 1050 2000 2050 3050
#
#
#               Impresora Brother Multifuncion Dcp-t420w Color
#
#
#               Cartucho Epson T140 T140220 T140320 T140420 Original Unidad
#
#
#               Cartucho Hp 675 Negro Original Cn690al 4000 4400 4575
#
#
#               Impresora Hp Multifuncion 2375 Deskjet Ink Advantage Via Usb
#
#
#               Toner Hp W2312a Amarillo Original Hp M182 M183 M155 Hp 215a
#
#
#               Cartucho Hp 74 Negro  + Hp 75 Color Originales Combo Pack 2u
#
#
#               Impresora Hp Laserjet Pro M454dw Color Wifi Duplex

# %%
# remove values with "antes"
pricelistp = [x for x in pricelist if "Antes:" not in x]
print(pricelistp)
# Out:
# ['194741 pesos', '90278 pesos', '313268 pesos', '102326 pesos', '581376 pesos', '6096 pesos', '233689 pesos', '222573 pesos', '11203 pesos', '62970 pesos', '18105 pesos', '13720 pesos', '185628 pesos', '3130 pesos', '36329 pesos', '95220 pesos', '11368 pesos', '3130 pesos', '122427 pesos', '10216 pesos', '6137 pesos', '16165 pesos', '3181 pesos', '71768 pesos', '146912 pesos', '2977 pesos', '10348 pesos', '214545 pesos', '5976 pesos', '12423 pesos', '15515 pesos', '77920 pesos', '58014 pesos', '19340 pesos', '178787 pesos', '15425 pesos', '2487 pesos', '121506 pesos', '13889 pesos', '12128 pesos', '334302 pesos', '3442 pesos', '9721 pesos', '75231 pesos', '4241 pesos', '3789 pesos', '19398 pesos', '15425 pesos', '12116 pesos', '111729 pesos']

# %%
print(len(pricelistp))
print(len(namelist))
# Out:
# 50
# 50

# %%
joindata = list(zip(pricelistp,namelist))
print(joindata)
# Out:
# [('194741 pesos', 'Impresora Plotter Hp Designjet T250 24 Pulgadas 61cm Wifi'), ('90278 pesos', 'Impresora Brother Multifuncion Dcp-t420w Color Cuotas'), ('313268 pesos', 'Plotter Hp Studio 24 Designjet 24 Pulgadas 5hb12a'), ('102326 pesos', 'Impresora Epson L6490 Ecotank Color Multifuncional A4 Con W'), ('581376 pesos', 'Plotter Hp Studio 24 Designjet 24 Pulgadas 5hb12a'), ('6096 pesos', 'Cartucho Hp 664 Negro + Color Combo 2675 2135 3635 3775 4675'), ('233689 pesos', 'Plotter Hp Designjet T250 24 Pulgadas (5hb06a) Cuo'), ('222573 pesos', 'Impresora Epson Ecotank L8160 Wi-fi Cuotas'), ('11203 pesos', 'Cartucho Hp 954xl Negro Original L0s71al 7740 8210 8710 8720'), ('62970 pesos', 'Impresora Brother Dcp-1212w Monocromatica Wi-fi Negra Cuo'), ('18105 pesos', 'Cartucho Hp 82 Negro Original Ch565a Designjet Hp 510 111'), ('13720 pesos', 'Toner Hp W1105a 105a Negro Original M107w 107a M135 M137'), ('185628 pesos', 'Impresora Epson Ecotank L8160 Wi-fi'), ('3130 pesos', 'Cartucho Hp 664 Negro F6v29al Orig. 2675 2135 3635 3775 4675'), ('36329 pesos', 'Combo Hp 950xl Negro + Hp 951xl Colores 8600 8620 8610'), ('95220 pesos', 'Impresora Hp Smart Tank 750 Mfp Wi-fi 6uu47a Cuotas'), ('11368 pesos', 'Cartucho Hp 950xl Negro Original Cn045al Hp 8100 8600 8610'), ('3130 pesos', 'Cartucho Hp 662 Negro O Tricolor X Unid. 1515 2515 2545 3545'), ('122427 pesos', 'Impresora Brother Dcp-t720dw Wifi Usb'), ('10216 pesos', 'Cartucho Hp 964xl Negro Original 3ja56a Officejet 9020 9010'), ('6137 pesos', 'Hp 662 Negro + 662 Tricolor Original 1515 2515 2545 Combo'), ('16165 pesos', 'Impresora Hp Multifuncion 2375 Deskjet Ink Advantage Via Usb'), ('3181 pesos', 'Cartucho Hp 667 Negro Original 3ym79al Hp Deskjet  2775'), ('71768 pesos', 'Toner Hp 147x W1470x High Yield Negro 25200 Copias M610'), ('146912 pesos', 'Impresora Brother Dcp-t720dw Wifi Usb Cuotas'), ('2977 pesos', 'Tinta Epson T673 Amarillo Original L805 L810 L850 L1800'), ('10348 pesos', 'Cartucho Hp 711 Cyan Magenta Amarillo Original Hp T120 T130'), ('214545 pesos', 'Impresora Laser Color Hp M479fdw W1a80a/l Wifi D/f Red Cuot'), ('5976 pesos', 'Cartucho Hp 951 Cyan Magenta Yellow 8600 8620 8610'), ('12423 pesos', 'Cartuchos Hp 60 Negro + Color Original - D110a F4280 F4480'), ('15515 pesos', 'Toner Hp Cf513a Magenta Original Hp 204a Laserjet Hp M180nw'), ('77920 pesos', 'Impresora Ricoh P311 Monocromática 408525t + Toner Ricoh'), ('58014 pesos', 'Toner Hp Cf237a Negro Original 37a M607 M608 M609 M631 M632'), ('19340 pesos', 'Toner Hp Cf217a Negro Original 17a -  M102w M130fw M134a'), ('178787 pesos', 'Impresora Laser Color Hp M479fdw W1a80a/l Wifi D/f Red Full'), ('15425 pesos', 'Toner Hp W2311a Cian Original M182 M183 M155 Hp 215a'), ('2487 pesos', 'Cartucho Epson T206 Negro Colores Xp2101 Original Individual'), ('121506 pesos', 'Impresora Epson L6490 Ecotank Color Multifuncional A4 Con W'), ('13889 pesos', 'Cartucho Hp 662xl Negro + Color Original 1515 2515 2545 3545'), ('12128 pesos', 'Cabezal Hp 11 C4810a C4811a C4812a C4813a Original Hp 500 10'), ('334302 pesos', 'Impresora Multifuncion Brother Mfc T4500dw A3 Color Doble Fa'), ('3442 pesos', 'Cartucho Hp 964 Cian Magenta Amarillo Original Por Unidad'), ('9721 pesos', 'Cartucho Hp 122xl Negro Ori Ch563hl 1000 1050 2000 2050 3050'), ('75231 pesos', 'Impresora Brother Multifuncion Dcp-t420w Color'), ('4241 pesos', 'Cartucho Epson T140 T140220 T140320 T140420 Original Unidad'), ('3789 pesos', 'Cartucho Hp 675 Negro Original Cn690al 4000 4400 4575'), ('19398 pesos', 'Impresora Hp Multifuncion 2375 Deskjet Ink Advantage Via Usb'), ('15425 pesos', 'Toner Hp W2312a Amarillo Original Hp M182 M183 M155 Hp 215a'), ('12116 pesos', 'Cartucho Hp 74 Negro  + Hp 75 Color Originales Combo Pack 2u'), ('111729 pesos', 'Impresora Hp Laserjet Pro M454dw Color Wifi Duplex')]

# %%
# export data to csv

import csv
fields = ['product','price']
rows = joindata

with open ('ArgColorImpresiones.csv', 'w', newline='') as f:
    write = csv.writer(f)
    write.writerow(fields)
    write.writerows(rows)
